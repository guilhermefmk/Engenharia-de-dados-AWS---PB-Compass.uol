# %% [markdown]
# # Tratando dados

# %%
google = pd.read_csv('../archives/googleplaystore.csv')

# %%
google.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
google.iloc[[3750]]
# Out:
#               App            Category  Rating Reviews  Size    Installs  Type  \
# 3750  РИА Новости  NEWS_AND_MAGAZINES     4.5   44274  8.0M  1,000,000+  Free
#
#      Price Content Rating            Genres    Last Updated Current Ver  \
# 3750     0       Everyone  News & Magazines  August 6, 2018       4.0.6
#
#      Android Ver
# 3750  4.4 and up

# %%
google.drop(index = 10472, inplace =  True)

# %%
google.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
google.drop_duplicates(subset = ['App'], inplace = True)

# %%
google.shape
# Out:
# (9659, 13)

# %%
google.sort_values(by=['App'], inplace=True)

# %%
google.sort_values(by=['App'])
# Out:
#                                                 App             Category  \
# 3750                                                  NEWS_AND_MAGAZINES
# 6006                                   BD Bangla TV               FAMILY
# 9117                                             DZ               FAMILY
# 7183                                    CD 2019 PRO    AUTO_AND_VEHICLES
# 4193                                              H       ART_AND_DESIGN
# ...                                             ...                  ...
# 3312                   weight conversion calculator                TOOLS
# 3652                 wetter.com - Weather and Radar              WEATHER
# 8644                    wikiHow: how to do anything  BOOKS_AND_REFERENCE
# 4811                        yHomework - Math Solver               FAMILY
# 2758  zulily - Shop Daily Deals in Fashion and Home             SHOPPING
#
#       Rating Reviews                Size     Installs  Type  Price  \
# ...

# %%
google.loc[:, 'App'] = google.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9659 entries, 8884 to 882
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   object
#  4   Size            9659 non-null   object
#  5   Installs        9659 non-null   object
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   object
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     9657 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 1.0+ MB

# %% [markdown]
# # Leia o arquivo actors.csv e faça os seguintes cálculos sobre o conjunto de dados utilizando Pandas
#
# • O ator/atriz com maior número de filmes e o respectivo número de filmes.
#
# • A média do número de filmes.
#
# • O ator/atriz com a maior média por filme.
#
# • O nome do(s) filme(s) mais frequente(s) e sua respectiva frequência.

# %%
import pandas as pd

# %%
actors = pd.read_csv('../archives/actors.csv', sep=',')

# %%
actors
# Out:
#                      Actor  Total Gross  Number of Movies  Average per Movie  \
# 0            Harrison Ford       4871.7                41              118.8
# 1        Samuel L. Jackson       4772.8                69               69.2
# 2           Morgan Freeman       4468.3                61               73.3
# 3                Tom Hanks       4340.8                44               98.7
# 4       Robert Downey, Jr.       3947.3                53               74.5
# 5             Eddie Murphy       3810.4                38              100.3
# 6               Tom Cruise       3587.2                36               99.6
# 7              Johnny Depp       3368.6                45               74.9
# 8            Michael Caine       3351.5                58               57.8
# 9       Scarlett Johansson       3341.2                37               90.3
# 10             Gary Oldman       3294.0                38               86.7
# ...

# %% [markdown]
# ## • O ator/atriz com maior número de filmes e o respectivo número de filmes.

# %%
MaisFilmes = actors[actors['Number of Movies'] == max(actors['Number of Movies'])].T
MaisFilmes
# Out:
#                                  19
# Actor                 Robert DeNiro
# Total Gross                  3081.3
# Number of Movies                 79
# Average per Movie              39.0
# #1 Movie           Meet the Fockers
# Gross                         279.3

# %% [markdown]
#
# ## • A média do número de filmes.

# %%
mediaFilmes = actors['Number of Movies'].mean()
mediaFilmes
# Out:
# 37.88

# %% [markdown]
# ## • O ator/atriz com a maior média por filme.

# %%
MaiorMediaPorFilme = actors[actors['Average per Movie'] == max(actors['Average per Movie'])].T
MaiorMediaPorFilme
# Out:
#                                              14
# Actor                           Anthony Daniels
# Total Gross                              3162.9
# Number of Movies                              7
# Average per Movie                         451.8
# #1 Movie           Star Wars: The Force Awakens
# Gross                                     936.7

# %% [markdown]
# ## • O nome do(s) filme(s) mais frequente(s) e sua respectiva frequência.

# %%
maxCountFilmes = actors[['#1 Movie']].groupby(['#1 Movie'])['#1 Movie'].count().max()
CountFilmes = actors[['#1 Movie']].groupby(['#1 Movie'])['#1 Movie'].count()
maxFilmes = actors[['#1 Movie']].groupby(['#1 Movie'])[['#1 Movie']].count()[CountFilmes == maxCountFilmes].rename(columns={'#1 Movie':'Count'}).reset_index()
maxFilmes
# Out:
#        #1 Movie  Count
# 0  The Avengers      6

# %% [markdown]
# # Leia o arquivo csv googleplaystore.csv e realize as seguintes atividades sobre o dataset utilizando Pandas:
#
# • Faça um gráfico de barras contendo os top 5 apps por número de instalação.
#
# • Faça um gráfico de pizza (pie chart) mostrando as categorias de apps existentes no dataset
# de acordo com a frequência em que elas aparecem.
#
# • Mostre qual o app mais caro existente no dataset.
#
# • Mostre quantos apps são classificados como “Mature 17+”.
#
# • Mostre o top 10 apps por número de reviews bem como o respectivo número de reviews.
# Ordene a lista de forma decrescente por número de reviews.

# %%
google.query('Category == "1.9"')
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
google[google['Android Ver'].isna()]
# Out:
#                                            App         Category  Rating  \
# 4453                    [substratum] Vacuum: P  PERSONALIZATION     4.4
# 4490                      Pi Dark [substratum]  PERSONALIZATION     4.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
#
#       Reviews    Size Installs  Type     Price Content Rating  \
# 4453      230     11M   1,000+  Paid     $1.49       Everyone
# 4490      189    2.1M  10,000+  Free         0       Everyone
# 10472    3.0M  1,000+     Free     0  Everyone            NaN
#
#                   Genres    Last Updated Current Ver Android Ver
# 4453     Personalization   July 20, 2018         4.4         NaN
# 4490     Personalization  March 27, 2018         1.1         NaN
# 10472  February 11, 2018          1.0.19  4.0 and up         NaN

# %%
google['Rating'].drop_duplicates()
# Out:
# 0              Everyone
# 3                  Teen
# 22         Everyone 10+
# 129          Mature 17+
# 298     Adults only 18+
# 7312            Unrated
# Name: Content Rating, dtype: object

# %%
google['Reviews'].drop_duplicates()
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 5           167
#           ...
# 10817       885
# 10826     88486
# 10829       603
# 10832      1195
# 10840    398307
# Name: Reviews, Length: 6002, dtype: object

# %%
google['Size'].drop_duplicates()
# Out:
# 0          19M
# 1          14M
# 2         8.7M
# 3          25M
# 4         2.8M
#          ...
# 10763     552k
# 10764     885k
# 10798    1020k
# 10832     582k
# 10833     619k
# Name: Size, Length: 462, dtype: object

# %%
google['Installs'].drop_duplicates()
# Out:
# 0               10,000+
# 1              500,000+
# 2            5,000,000+
# 3           50,000,000+
# 4              100,000+
# 5               50,000+
# 7            1,000,000+
# 12          10,000,000+
# 15               5,000+
# 139        100,000,000+
# 152      1,000,000,000+
# 329              1,000+
# 342        500,000,000+
# 478                 50+
# 479                100+
# 605                500+
# 625                 10+
# 649                  1+
# 659                  5+
# 4465                 0+
# 9148                  0
# 10472              Free
# Name: Installs, dtype: object

# %%
google['Type'].drop_duplicates()
# Out:
# 0        Free
# 234      Paid
# 10472       0
# Name: Type, dtype: object

# %%
google['Content Rating'].drop_duplicates()
# Out:
# 0              Everyone
# 3                  Teen
# 22         Everyone 10+
# 129          Mature 17+
# 298     Adults only 18+
# 7312            Unrated
# Name: Content Rating, dtype: object

# %%
google['Genres'].drop_duplicates()
# Out:
# 0                           Art & Design
# 1              Art & Design;Pretend Play
# 4                Art & Design;Creativity
# 23       Art & Design;Action & Adventure
# 49                       Auto & Vehicles
#                       ...
# 9674                  Strategy;Education
# 9688                 Racing;Pretend Play
# 10218           Communication;Creativity
# 10472                  February 11, 2018
# 10526                Strategy;Creativity
# Name: Genres, Length: 120, dtype: object

# %%
google['Last Updated'].drop_duplicates()
# Out:
# 0          January 7, 2018
# 1         January 15, 2018
# 2           August 1, 2018
# 3             June 8, 2018
# 4            June 20, 2018
#                ...
# 10808    November 25, 2014
# 10818         May 19, 2016
# 10830     January 20, 2014
# 10832    February 16, 2014
# 10833       March 23, 2014
# Name: Last Updated, Length: 1378, dtype: object

# %%
google['Current Ver'].drop_duplicates()
# Out:
# 0                     1.0.0
# 1                     2.0.0
# 2                     1.2.4
# 3        Varies with device
# 4                       1.1
#                 ...
# 10800                  6.04
# 10803               1.5.447
# 10817            1.0.612928
# 10819                 0.3.4
# 10831             2.0.148.0
# Name: Current Ver, Length: 2833, dtype: object

# %%
google['Android Ver'].drop_duplicates()
# Out:
# 0              4.0.3 and up
# 3                4.2 and up
# 4                4.4 and up
# 5                2.3 and up
# 8                3.0 and up
# 10               4.1 and up
# 11               4.0 and up
# 37             2.3.3 and up
# 42       Varies with device
# 58               2.2 and up
# 72               5.0 and up
# 80               6.0 and up
# 133              1.6 and up
# 144              1.5 and up
# 170              2.1 and up
# 173              7.0 and up
# 185              5.1 and up
# 203              4.3 and up
# 350           4.0.3 - 7.1.1
# 458              2.0 and up
# 821              3.2 and up
# 1024            4.4W and up
# 1532             7.1 and up
# 1572            7.0 - 7.1.1
# 2484             8.0 and up
# 2841              5.0 - 8.0
# 2915             3.1 and up
# 4054           2.0.1 and up
# 4151            4.1 - 7.1.1
# 4453                    NaN
# 7571              5.0 - 6.0
# 8919             1.0 and up
# 9310            2.2 - 7.1.1
# ...

# %%
google[google['Type'].isna()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
google['Type'].fillna('Free', inplace = True)

# %%
google[google['Content Rating'].isna()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
google['Content Rating'].fillna('Unrated', inplace = True)
